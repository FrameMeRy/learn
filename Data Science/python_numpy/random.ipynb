# %%
import numpy as np

# %%
np.random.random((2,2))
# Out:
# array([[0.75631815, 0.37473889],
#        [0.66000711, 0.02613977]])

# %%
np.random.random((10,10))
# Out:
# array([[3.12692373e-01, 9.10798791e-02, 3.94199362e-01, 3.17415459e-01,
#         9.67309851e-01, 9.18808346e-01, 5.09448083e-02, 2.06323097e-01,
#         5.97473246e-01, 9.91487712e-01],
#        [8.49392839e-01, 8.96609939e-01, 8.22642902e-02, 6.62799248e-04,
#         7.05449562e-01, 6.44136687e-01, 1.39199270e-01, 7.26335323e-01,
#         1.46689188e-01, 7.69292754e-01],
#        [9.10425775e-01, 1.06252218e-01, 5.51991817e-01, 2.17654014e-01,
#         6.62214128e-01, 9.61287275e-01, 7.29645433e-01, 8.79310948e-01,
#         9.06425897e-01, 7.19092558e-01],
#        [9.50386521e-01, 7.24629329e-03, 7.52818819e-01, 7.82917927e-01,
#         8.05400229e-01, 7.98352062e-01, 4.53053814e-01, 4.80408325e-01,
#         5.38694100e-01, 5.93563258e-01],
#        [8.72697848e-01, 6.28480236e-01, 4.69688830e-01, 1.55660001e-01,
#         1.33859966e-02, 4.10592473e-01, 8.66210148e-01, 7.96714569e-01,
#         4.27406192e-01, 8.39657871e-01],
# ...
